# %%
import pandas as pd

# Use double backslashes or forward slashes in the file path
file_path = "bases/proy_1025_depto_caba.xls"

# Read the Excel file into a DataFrame from the second sheet
poblaciontotal = pd.read_excel(file_path, sheet_name=1)

# Display the first few rows of the DataFrame
print(poblaciontotal.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# g:\Mi unidad\Proyecto henry 2 (copia)\Data and notebooks\3.poblacion.ipynb Cell 1 line 7
#       <a href='vscode-notebook-cell:/g%3A/Mi%20unidad/Proyecto%20henry%202%20%28copia%29/Data%20and%20notebooks/3.poblacion.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> file_path = "bases/proy_1025_depto_caba.xls"
#       <a href='vscode-notebook-cell:/g%3A/Mi%20unidad/Proyecto%20henry%202%20%28copia%29/Data%20and%20notebooks/3.poblacion.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a> # Read the Excel file into a DataFrame from the second sheet
# ----> <a href='vscode-notebook-cell:/g%3A/Mi%20unidad/Proyecto%20henry%202%20%28copia%29/Data%20and%20notebooks/3.poblacion.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a> poblaciontotal = pd.read_excel(file_path, sheet_name=1)
# ...
